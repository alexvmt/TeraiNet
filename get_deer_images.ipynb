# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/tiger_detection/
# Out:
# /content/drive/MyDrive/tiger_detection

# %%
# !zcat lila_image_urls_and_labels.csv.zip | awk -F ',' 'NR==1 || $9 == "deer"' > cervidae.csv
# Out:
# gzip: lila_image_urls_and_labels.csv.zip: invalid compressed data--length error

# %%
# !wc -l cervidae.csv
# Out:
# 263369 cervidae.csv

# %%
!(head -n 1 cervidae.csv && shuf -n 5000 cervidae.csv) > cervidae_sample.csv

# %%
# !awk -F ',' 'NR>1 {print $2}' cervidae_sample.csv | while read url; do wget -q -P images/cervidae "$url"; done
