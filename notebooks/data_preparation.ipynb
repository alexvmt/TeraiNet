# %% [markdown]
# # Data preparation
#
# 1. Download image URLs and labels from LILA BC
# 2. For each selected species: sample and download images, create train test split if applicable
# 3. Run MegaDetector on all images
# 4. Run mewc-snip on all images
# 5. Copy snipped images to Drive

# %% [markdown]
# ## Setup

# %%
from google.colab import drive

import os
import numpy as np
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install megadetector udocker
# Out:
# Requirement already satisfied: megadetector in /usr/local/lib/python3.10/dist-packages (5.0.21)
# Requirement already satisfied: udocker in /usr/local/lib/python3.10/dist-packages (1.3.17)
# Requirement already satisfied: Pillow>=9.5 in /usr/local/lib/python3.10/dist-packages (from megadetector) (11.0.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from megadetector) (4.66.6)
# Requirement already satisfied: jsonpickle>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from megadetector) (4.0.0)
# Requirement already satisfied: humanfriendly>=10.0 in /usr/local/lib/python3.10/dist-packages (from megadetector) (10.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from megadetector) (1.23.5)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from megadetector) (3.8.0)
# Requirement already satisfied: opencv-python>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from megadetector) (4.10.0.84)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from megadetector) (2.32.3)
# Requirement already satisfied: pyqtree>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from megadetector) (1.0.0)
# Requirement already satisfied: seaborn>=0.12.2 in /usr/local/lib/python3.10/dist-packages (from megadetector) (0.13.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from megadetector) (1.5.2)
# Requirement already satisfied: pandas>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from megadetector) (2.2.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from megadetector) (6.0.2)
# Requirement already satisfied: ultralytics-yolov5==0.1.1 in /usr/local/lib/python3.10/dist-packages (from megadetector) (0.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (1.13.1)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (0.20.1+cu121)
# Requirement already satisfied: protobuf<=3.20.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (3.20.1)
# Requirement already satisfied: fire in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (0.7.0)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (2.17.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (7.34.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (5.9.5)
# Requirement already satisfied: thop in /usr/local/lib/python3.10/dist-packages (from ultralytics-yolov5==0.1.1->megadetector) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->megadetector) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->megadetector) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->megadetector) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->megadetector) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->megadetector) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->megadetector) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->megadetector) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.1->megadetector) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.1.1->megadetector) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->megadetector) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->megadetector) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->megadetector) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->megadetector) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.1->megadetector) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.1->megadetector) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->megadetector) (1.16.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics-yolov5==0.1.1->megadetector) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics-yolov5==0.1.1->megadetector) (1.68.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics-yolov5==0.1.1->megadetector) (3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics-yolov5==0.1.1->megadetector) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics-yolov5==0.1.1->megadetector) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.4.1->ultralytics-yolov5==0.1.1->megadetector) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics-yolov5==0.1.1->megadetector) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics-yolov5==0.1.1->megadetector) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics-yolov5==0.1.1->megadetector) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics-yolov5==0.1.1->megadetector) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics-yolov5==0.1.1->megadetector) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->ultralytics-yolov5==0.1.1->megadetector) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.7.0->ultralytics-yolov5==0.1.1->megadetector) (1.3.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->ultralytics-yolov5==0.1.1->megadetector) (2.5.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ultralytics-yolov5==0.1.1->megadetector) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ultralytics-yolov5==0.1.1->megadetector) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ultralytics-yolov5==0.1.1->megadetector) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ultralytics-yolov5==0.1.1->megadetector) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->ultralytics-yolov5==0.1.1->megadetector) (3.0.2)

# %%
# !udocker --allow-root install
# !udocker --allow-root pull zaandahl/mewc-snip
# Out:
# Info: downloading layer sha256:1246a535b13ec540da6cc956742d3f57cc885eeb3bc8a13a1acf814cb7dbc408
# Info: downloading layer sha256:8ea64ddcde0323c874d115e0a770aae1fa0a6377a445f30791487fc3a1bf0873
# Info: downloading layer sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Info: downloading layer sha256:e380b201f9cfc7dd5d52f5e806863b14c881e26a6d972a34534ed69642d701b3
# Info: downloading layer sha256:dff5477a4a4517d28aa8e484bc04e13f82681e4e4e49d3ba9c403f8baf4ecde8
# Info: downloading layer sha256:d230d1ae81f7af7b367d98c0b142f9065fa0ee6f16c5d9e11a1fd59b59d56092
# Info: downloading layer sha256:c43b5347d05de26c8823110aaa5fb6d21fd0ae396ffd8ac29296f20c002def9d
# Info: downloading layer sha256:41114abec237a1f9dea1684b857a3411a69f4391b3429e2ce8705eb9a19b4203
# Info: downloading layer sha256:3a39b83ae0ab6d04f26436dc0a6f76ccd06e12298a0d78962bae8a3bacd8faa8
# Info: downloading layer sha256:cdbc978275d45d56de7d042b67015d7d4500dbfa4be00d0bdd1a232d78a275d2
# Info: downloading layer sha256:b2392c294dc2d4dbf75d79fe7afd7761849ccc28743598a3408586d279551988
# Info: downloading layer sha256:229cc92bf6588c4bbf7081a7b4112a26d197a008cd3a6008ab15b4e212916c38
# Info: downloading layer sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Info: downloading layer sha256:676d495f32a67e2dbb30c2d6b7e7997a084202d85badb3abf601f5a55329b831
# Info: downloading layer sha256:2c862a671e04a43b77501285eb0043eb26310c365dcf12b05eefdb0ef3b03356
# Info: downloading layer sha256:44e2b30be3df8960a4f917a09d5d681b9dac8b9059a31687557d8dfc688112d2
# Info: downloading layer sha256:a7548917b9e46af9c12ca60b1a397c82eaf4f62a7792b879350d573d49745baa
# Info: downloading layer sha256:ea030c493986ce9372bcab3b745d26b38865d0c48b0c50b70a432871b93e1b04
# Info: downloading layer sha256:2185b402c9ca9c9a1e03db5b387fe9a1dc43c1247bf41199b18e901c2e44ff35
# Info: downloading layer sha256:4f4fb700ef54461cfa02571ae0db9a0dc1e0cdb5577484a6d75e68dc38e8acc1
# Info: downloading layer sha256:035a286326d65b413051a4c52e7df0037d89f1075f7be98c9586d1c856ace994
# Info: downloading layer sha256:4ade0a4bc5d597c845bc3c27c47453522019ee188adbc4110029bbea11e5adec
# Info: downloading layer sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8ec3214c584e02b3a8

# %%
def add_subset_column(df, train_ratio, seed=42):
    """
    Adds a 'subset' column to the DataFrame, splitting data into 'train' and 'test' subsets.

    Parameters:
        df (pd.DataFrame): The input DataFrame.
        train_ratio (float): The ratio of the 'train' subset (e.g., 0.8 for 80% train).
        seed (int, optional): Seed for reproducibility. Default is 42.

    Returns:
        pd.DataFrame: The DataFrame with an additional 'subset' column.
    """
    if not 0 <= train_ratio <= 1:
        raise ValueError("train_ratio must be between 0 and 1.")

    # Set the random seed for reproducibility
    np.random.seed(seed)

    # Generate random values to assign subsets
    random_values = np.random.rand(len(df))

    # Assign subsets based on the train_ratio
    df['subset'] = np.where(random_values < train_ratio, 'train', 'test')

    return df

# %%
project_dir = 'drive/MyDrive/tiger_classification'

scripts_dir = project_dir + '/scripts/'
sample_images_script = scripts_dir + 'sample_images_from_lila_bc.sh'
download_images_script = scripts_dir + 'download_images_from_lila_bc.sh'
prep_amur_tiger_images_script = scripts_dir + 'prep_amur_tiger_images.sh'
run_md_script = scripts_dir + 'run_megadetector.py'
copy_snipped_images_script = scripts_dir + 'copy_snipped_images.sh'

md_dir = project_dir + '/megadetector/'
md_file = md_dir + 'md_v5a.0.0.pt'
md_out_file = 'md_out.json'

images_dir = 'images'
# !mkdir -p "$images_dir"

# %%
remove_images = True
if remove_images:
  # !rm -rf "$project_dir/$images_dir"
  # !mkdir -p "$project_dir/$images_dir"

# %% [markdown]
# ## Download image URLs and labels from LILA BC

# %%
# !wget -O lila_image_urls_and_labels.csv.zip -nc "https://lila.science/public/lila_image_urls_and_labels.csv.zip"
# Out:
# --2024-11-29 18:23:52--  https://lila.science/public/lila_image_urls_and_labels.csv.zip
# Resolving lila.science (lila.science)... 20.83.252.133
# Connecting to lila.science (lila.science)|20.83.252.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 457425682 (436M) [application/zip]
# Saving to: ‘lila_image_urls_and_labels.csv.zip’
#
#  lila_image_urls_an  44%[=======>            ] 191.99M   106MB/s

# %%
![ -f lila_image_urls_and_labels.csv ] || unzip lila_image_urls_and_labels.csv.zip
# Out:
# Archive:  lila_image_urls_and_labels.csv.zip
#   inflating: lila_image_urls_and_labels.csv

# %%
urls_and_labels = 'lila_image_urls_and_labels.csv'

# %% [markdown]
# Check taxonomy mapping to find relevant species:
# https://lila.science/public/lila-taxonomy-mapping_release.csv

# %% [markdown]
# ## Sample images

# %% [markdown]
# ### Tiger

# %% [markdown]
# #### LILA BC
# Don't take a sample but get all tiger images from LILA BC since there are not many.

# %%
# get image urls
species = 'panthera tigris'
samples_file = images_dir + '/' + species.replace(' ', '_') + '_lila_bc.csv'
# !time awk -F ',' -v species="$species" 'NR==1 || $10 == species' "$urls_and_labels" > "$samples_file"
# !cat "$samples_file" | wc -l
# Out:
# real	1m35.277s
# user	0m23.504s
# sys	0m4.678s
# 322

# %%
# copy samples file to drive
# !cp "$samples_file" "$project_dir/$images_dir/$(basename "$samples_file")"

# %%
# add subset column to samples file
df = pd.read_csv(samples_file)
df['subset'] = 'test2'
df.to_csv(samples_file, index=False)

# %%
# download images
class_number = 1
# !time bash "$download_images_script" "$samples_file" "$class_number" "$images_dir"
# Out:
# Downloading images into directory: images...
# Error downloading https://storage.googleapis.com/public-datasets-lila/wcs-unzipped/animals/0405/0132.jpg
# Error downloading https://storage.googleapis.com/public-datasets-lila/wcs-unzipped/animals/0405/0133.jpg
# Error downloading https://storage.googleapis.com/public-datasets-lila/wcs-unzipped/animals/0405/0134.jpg
# Error downloading https://storage.googleapis.com/public-datasets-lila/wcs-unzipped/animals/0405/0135.jpg
# Error downloading https://storage.googleapis.com/public-datasets-lila/wcs-unzipped/animals/0405/0138.jpg
# Total failed downloads: 5
# Download complete. Files saved to images.
#
# real	0m41.339s
# user	0m3.375s
# sys	0m3.259s

# %%
# remove worst and wrongly labeled tiger images from test2
# this kind of quality control is only feasible because there are ~300 images
images_to_remove = [
    'class_1_test2_46.jpg',
    'class_1_test2_49.jpg',
    'class_1_test2_91.jpg',
    'class_1_test2_134.jpg',
    'class_1_test2_135.jpg',
    'class_1_test2_136.jpg',
    'class_1_test2_158.jpg', # goat
    'class_1_test2_159.jpg', # goat
    'class_1_test2_220.jpg',
    'class_1_test2_311.jpg'
]

for file_name in images_to_remove:
    file_path = os.path.join(images_dir, file_name)
    try:
        os.remove(file_path)
        print(f'Deleted: {file_path}')
    except FileNotFoundError:
        print(f'File not found: {file_path}')
    except PermissionError:
        print(f'Permission denied: {file_path}')
    except Exception as e:
        print(f'Error deleting {file_path}: {e}')
# Out:
# Deleted: images/class_1_test2_46.jpg
# Deleted: images/class_1_test2_49.jpg
# Deleted: images/class_1_test2_91.jpg
# Deleted: images/class_1_test2_134.jpg
# Deleted: images/class_1_test2_135.jpg
# Deleted: images/class_1_test2_136.jpg
# Deleted: images/class_1_test2_158.jpg
# Deleted: images/class_1_test2_159.jpg
# Deleted: images/class_1_test2_220.jpg
# Deleted: images/class_1_test2_311.jpg

# %% [markdown]
# #### Amur tiger re-identification challenge
# These images are a substitute for "real" camera trap images because openly available camera trap images of tigers are scarce.

# %%
# download, unpack and prep train images
# !wget -O "$images_dir/atrw_detection_train.tar.gz" https://storage.googleapis.com/public-datasets-lila/cvwc2019/train/atrw_detection_train.tar.gz
# !tar -xzf "$images_dir/atrw_detection_train.tar.gz" -C "$images_dir"
# !time bash "$prep_amur_tiger_images_script" "$images_dir/trainval" 1 train "$images_dir"
# Out:
# --2024-11-29 18:29:30--  https://storage.googleapis.com/public-datasets-lila/cvwc2019/train/atrw_detection_train.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.197.207, 74.125.135.207, 74.125.142.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.197.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2288778168 (2.1G) [application/x-tar]
# Saving to: ‘images/atrw_detection_train.tar.gz’
#
# images/atrw_detecti 100%[===================>]   2.13G   126MB/s    in 17s
#
# 2024-11-29 18:29:47 (131 MB/s) - ‘images/atrw_detection_train.tar.gz’ saved [2288778168/2288778168]
#
# All files moved and renamed. Source directory images/trainval removed.
#
# real	0m12.614s
# user	0m2.667s
# sys	0m6.562s

# %%
# download, unpack and prep test images
# !wget -O "$images_dir/atrw_detection_test.tar.gz" https://storage.googleapis.com/public-datasets-lila/cvwc2019/test/atrw_detection_test.tar.gz
# !tar -xzf "$images_dir/atrw_detection_test.tar.gz" -C "$images_dir"
# !time bash "$prep_amur_tiger_images_script" "$images_dir/test" 1 test "$images_dir"
# Out:
# --2024-11-29 18:30:39--  https://storage.googleapis.com/public-datasets-lila/cvwc2019/test/atrw_detection_test.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.99.207, 142.250.107.207, 142.251.188.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.99.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1493058467 (1.4G) [application/x-tar]
# Saving to: ‘images/atrw_detection_test.tar.gz’
#
# images/atrw_detecti 100%[===================>]   1.39G   109MB/s    in 10s
#
# 2024-11-29 18:30:50 (143 MB/s) - ‘images/atrw_detection_test.tar.gz’ saved [1493058467/1493058467]
#
# All files moved and renamed. Source directory images/test removed.
#
# real	0m6.924s
# user	0m1.526s
# sys	0m3.742s

# %% [markdown]
# ### Lynx

# %%
# sample images
column_to_filter = 'scientific_name'
values_to_filter = 'lynx rufus'
sample_size = 2000
# !time bash "$sample_images_script" "$urls_and_labels" "$column_to_filter" "$values_to_filter" "$sample_size" "$images_dir"
# Out:
# Sampling 2000 rows with scientific_name equal to any of {lynx rufus} using seed 42...
# Sampling complete. Result written to images/lynx_rufus_sample_2000.csv.
#
# real	0m33.237s
# user	0m21.729s
# sys	0m4.543s

# %%
# copy samples file to drive
samples_file = images_dir + '/' + values_to_filter.replace(' ', '_') + '_sample_' + str(sample_size) + '.csv'
# !cp "$samples_file" "$project_dir/$images_dir/$(basename "$samples_file")"

# %%
# add subset column to samples file
df = pd.read_csv(samples_file)
train_ratio = 0.7
df = add_subset_column(df, train_ratio)
df.to_csv(samples_file, index=False)

# %%
# download images
class_number = 2
# !time bash "$download_images_script" "$samples_file" "$class_number" "$images_dir"
# Out:
# Downloading images into directory: images...
# All images successfully downloaded.
# Download complete. Files saved to images.
#
# real	3m55.796s
# user	0m20.066s
# sys	0m18.065s

# %% [markdown]
# ### Black bear

# %%
# sample images
column_to_filter = 'common_name'
values_to_filter = 'american black bear,asian black bear'
sample_size = 2000
# !time bash "$sample_images_script" "$urls_and_labels" "$column_to_filter" "$values_to_filter" "$sample_size" "$images_dir"
# Out:
# Sampling 2000 rows with common_name equal to any of {american black bear,asian black bear} using seed 42...
# Sampling complete. Result written to images/american_black_bear_asian_black_bear_sample_2000.csv.
#
# real	0m34.847s
# user	0m23.291s
# sys	0m4.436s

# %%
# copy samples file to drive
samples_file = images_dir + '/' + values_to_filter.replace(' ', '_').replace(',', '_') + '_sample_' + str(sample_size) + '.csv'
# !cp "$samples_file" "$project_dir/$images_dir/$(basename "$samples_file")"

# %%
# add subset column to samples file
df = pd.read_csv(samples_file)
train_ratio = 0.7
df = add_subset_column(df, train_ratio)
df.to_csv(samples_file, index=False)

# %%
# download images
class_number = 3
# !time bash "$download_images_script" "$samples_file" "$class_number" "$images_dir"
# Out:
# Downloading images into directory: images...
# All images successfully downloaded.
# Download complete. Files saved to images.
#
# real	3m50.649s
# user	0m20.496s
# sys	0m19.143s

# %% [markdown]
# ### Deer

# %%
# sample images
column_to_filter = 'common_name'
values_to_filter = 'deer'
sample_size = 2000
# !time bash "$sample_images_script" "$urls_and_labels" "$column_to_filter" "$values_to_filter" "$sample_size" "$images_dir"
# Out:
# Sampling 2000 rows with common_name equal to any of {deer} using seed 42...
# Sampling complete. Result written to images/deer_sample_2000.csv.
#
# real	0m50.766s
# user	0m21.605s
# sys	0m6.490s

# %%
# copy samples file to drive
samples_file = images_dir + '/' + values_to_filter.replace(' ', '_') + '_sample_' + str(sample_size) + '.csv'
# !cp "$samples_file" "$project_dir/$images_dir/$(basename "$samples_file")"

# %%
# add subset column to samples file
df = pd.read_csv(samples_file)
train_ratio = 0.7
df = add_subset_column(df, train_ratio)
df.to_csv(samples_file, index=False)

# %%
# download images
class_number = 4
# !time bash "$download_images_script" "$samples_file" "$class_number" "$images_dir"
# Out:
# Downloading images into directory: images...
# All images successfully downloaded.
# Download complete. Files saved to images.
#
# real	4m12.229s
# user	0m21.552s
# sys	0m21.932s

# %% [markdown]
# ### Bird

# %%
# sample images
column_to_filter = 'common_name'
values_to_filter = 'bird'
sample_size = 2000
# !time bash "$sample_images_script" "$urls_and_labels" "$column_to_filter" "$values_to_filter" "$sample_size" "$images_dir"
# Out:
# Sampling 2000 rows with common_name equal to any of {bird} using seed 42...
# Sampling complete. Result written to images/bird_sample_2000.csv.
#
# real	0m42.027s
# user	0m23.770s
# sys	0m5.360s

# %%
# copy samples file to drive
samples_file = images_dir + '/' + values_to_filter.replace(' ', '_') + '_sample_' + str(sample_size) + '.csv'
# !cp "$samples_file" "$project_dir/$images_dir/$(basename "$samples_file")"

# %%
# add subset column to samples file
df = pd.read_csv(samples_file)
train_ratio = 0.7
df = add_subset_column(df, train_ratio)
df.to_csv(samples_file, index=False)

# %%
# download images
class_number = 5
# !time bash "$download_images_script" "$samples_file" "$class_number" "$images_dir"
# Out:
# Downloading images into directory: images...
# All images successfully downloaded.
# Download complete. Files saved to images.
#
# real	4m5.901s
# user	0m21.103s
# sys	0m21.665s

# %% [markdown]
# ## Run MegaDetector

# %%
# run megadetector
# !time python "$run_md_script" "$images_dir" "$md_file"
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#  61% 7740/12734 [23:01<17:07,  4.86it/s]Processing image images/class_3_train_1539.jpg
#  61% 7741/12734 [23:01<17:03,  4.88it/s]Processing image images/class_3_train_154.jpg
#  61% 7742/12734 [23:01<17:08,  4.85it/s]Processing image images/class_3_train_1540.jpg
#  61% 7743/12734 [23:01<17:23,  4.79it/s]Processing image images/class_3_train_1542.JPG
#  61% 7744/12734 [23:02<18:06,  4.59it/s]Processing image images/class_3_train_1543.JPG
#  61% 7745/12734 [23:02<17:38,  4.71it/s]Processing image images/class_3_train_1544.jpg
# 100% 12725/12734 [40:57<00:01,  4.93it/s]Processing image images/class_5_train_988.jpg
# 100% 12726/12734 [40:57<00:01,  4.90it/s]Processing image images/class_5_train_989.JPG
# 100% 12727/12734 [40:57<00:01,  4.79it/s]Processing image images/class_5_train_99.jpg
# 100% 12728/12734 [40:57<00:01,  4.95it/s]Processing image images/class_5_train_992.jpg
# 100% 12729/12734 [40:58<00:00,  5.00it/s]Processing image images/class_5_train_993.JPG
# 100% 12730/12734 [40:58<00:00,  4.75it/s]Processing image images/class_5_train_994.jpg
# 100% 12731/12734 [40:58<00:00,  4.89it/s]Processing image images/class_5_train_995.jpg
# 100% 12732/12734 [40:58<00:00,  5.04it/s]Processing image images/class_5_train_996.jpg
# 100% 12733/12734 [40:58<00:00,  5.10it/s]Processing image images/class_5_train_998.jpg
# 100% 12734/12734 [40:59<00:00,  5.18it/s]
# Output file saved at images/md_out.json
#
# real	42m2.072s
# user	36m43.250s
# sys	0m51.376s

# %%
# copy megadetector output file to drive
# !cp "$images_dir/$md_out_file" "$project_dir/$images_dir/$md_out_file"

# %% [markdown]
# ## Run mewc-snip

# %%
# run mewc-snip
# !time udocker --allow-root run \
  --volume "/content/$images_dir":/images \
  zaandahl/mewc-snip
# Out:
#
#  ******************************************************************************
#  *                                                                            *
#  *               STARTING 6ec37875-6bc7-3dd1-9633-01e446d71570                *
#  *                                                                            *
#  ******************************************************************************
#  executing: python
# Processing 12734 images from md_out.json
#   0% 2/12734 [00:00<46:37,  4.55it/s]  /opt/conda/lib/python3.10/site-packages/PIL/TiffImagePlugin.py:858: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 100% 12734/12734 [24:15<00:00,  8.75it/s]
#
# real	29m39.591s
# user	24m19.505s
# sys	2m5.280s

# %% [markdown]
# ## Copy snipped images to Drive

# %%
# create target directory structure
# !mkdir -p "$project_dir/$images_dir/train"
# !mkdir -p "$project_dir/$images_dir/test"
# !mkdir -p "$project_dir/$images_dir/test2"

# %%
# copy snipped images to drive
# !time bash "$copy_snipped_images_script" "$images_dir/snips" "$project_dir/$images_dir" 5
# Out:
# Files copied successfully.
#
# real	8m42.068s
# user	1m7.714s
# sys	2m56.842s

# %%
# !ls "$project_dir/$images_dir/train/class_1" | wc -l
# !ls "$project_dir/$images_dir/train/class_2" | wc -l
# !ls "$project_dir/$images_dir/train/class_3" | wc -l
# !ls "$project_dir/$images_dir/train/class_4" | wc -l
# !ls "$project_dir/$images_dir/train/class_5" | wc -l
# Out:
# 4896
# 1451
# 1667
# 2101
# 1918

# %%
# !ls "$project_dir/$images_dir/test/class_1" | wc -l
# !ls "$project_dir/$images_dir/test/class_2" | wc -l
# !ls "$project_dir/$images_dir/test/class_3" | wc -l
# !ls "$project_dir/$images_dir/test/class_4" | wc -l
# !ls "$project_dir/$images_dir/test/class_5" | wc -l
# Out:
# 2825
# 626
# 677
# 920
# 842

# %%
# !ls "$project_dir/$images_dir/test2/class_1" | wc -l
# Out:
# 307
