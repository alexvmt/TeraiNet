# %% [markdown]
# # Download images

# %% [markdown]
# ## Setup

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/tiger_detection/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/tiger_detection/'
# /content/drive/MyDrive/tiger_detection

# %% [markdown]
# ## Download images

# %%
# !time bash scripts/download_images_from_lila_bc.sh images/bird/bird_sample_1000.csv
# Out:
# ...
# All images successfully downloaded.
# ...

# %%
# !time bash scripts/download_images_from_lila_bc.sh images/canis_lupus/canis_lupus_sample_1000.csv
# Out:
# ...
# Total missing images: 62
# ...

# %%
# !time bash scripts/download_images_from_lila_bc.sh images/deer/deer_sample_1000.csv
# Out:
# ...
# ^C

# %%
# !time bash scripts/download_images_from_lila_bc.sh images/lynx_rufus/lynx_rufus_sample_1000.csv
# Out:
# ...
# ^C

# %%
# !time bash scripts/download_images_from_lila_bc.sh images/panthera_tigris/panthera_tigris.csv

# %%
# !time bash scripts/download_images_from_lila_bc.sh images/ursus_thibetanus/ursus_thibetanus_sample_1000.csv
