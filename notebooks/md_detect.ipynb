# %% [markdown]
# # Run MegaDetector on downloaded images

# %% [markdown]
# ## Setup

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/tiger_detection/
# Out:
# /content/drive/MyDrive/tiger_detection

# %%
# !pip install megadetector

# %% [markdown]
# ## Run MegaDetector

# %%
# !python scripts/run_megadetector.py images/bird/downloaded_images
# Out:
# PyTorch reports 1 available CUDA devices
# GPU available: True
# 2024-11-21 20:52:46.496879: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-21 20:52:46.516762: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-21 20:52:46.522672: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-21 20:52:46.537221: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !python scripts/run_megadetector.py images/canis_lupus/downloaded_images
# Out:
# PyTorch reports 1 available CUDA devices
# GPU available: True
# 2024-11-21 20:57:52.204815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-21 20:57:52.225310: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-21 20:57:52.231552: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-21 20:57:52.246215: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !python scripts/run_megadetector.py images/deer/downloaded_images
# Out:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1078, in _handle_fromlist
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.10/dist-packages/torch/_meta_registrations.py", line 10, in <module>
#     from torch._decomp import (
#   File "/usr/local/lib/python3.10/dist-packages/torch/_decomp/__init__.py", line 249, in <module>
#     import torch._decomp.decompositions
#   File "/usr/local/lib/python3.10/dist-packages/torch/_decomp/decompositions.py", line 15, in <module>
#     import torch._prims as prims
#   File "/usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py", line 786, in <module>
#     floor = _make_elementwise_unary_prim(
#   File "/usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py", line 491, in _make_elementwise_unary_prim
#     return _make_prim(
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# !python scripts/run_megadetector.py images/lynx_rufus/downloaded_images
# Out:
# PyTorch reports 1 available CUDA devices
# GPU available: True
# 2024-11-21 20:58:41.323666: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-21 20:58:41.343989: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-21 20:58:41.349987: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-21 20:58:41.364364: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# !python scripts/run_megadetector.py images/panthera_tigris/downloaded_images
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/tiger_detection/scripts/run_megadetector.py", line 26, in <module>
#     image_file_names = path_utils.find_images(image_folder, recursive=True)
#   File "/usr/local/lib/python3.10/dist-packages/megadetector/utils/path_utils.py", line 386, in find_images
#     strings = glob.glob(os.path.join(dirname, '**', '*.*'), recursive=True)
#   File "/usr/lib/python3.10/glob.py", line 24, in glob
#     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#   File "/usr/lib/python3.10/glob.py", line 86, in _iglob
#     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly):
#   File "/usr/lib/python3.10/glob.py", line 94, in _glob1
#     names = _listdir(dirname, dir_fd, dironly)
#   File "/usr/lib/python3.10/glob.py", line 164, in _listdir
#     return list(it)
#   File "/usr/lib/python3.10/glob.py", line 149, in _iterdir
#     if not dironly or entry.is_dir():
# ...

# %%
# !python scripts/run_megadetector.py images/ursus_thibetanus/downloaded_images
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/tiger_detection/scripts/run_megadetector.py", line 26, in <module>
#     image_file_names = path_utils.find_images(image_folder, recursive=True)
#   File "/usr/local/lib/python3.10/dist-packages/megadetector/utils/path_utils.py", line 386, in find_images
#     strings = glob.glob(os.path.join(dirname, '**', '*.*'), recursive=True)
#   File "/usr/lib/python3.10/glob.py", line 24, in glob
#     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#   File "/usr/lib/python3.10/glob.py", line 86, in _iglob
#     for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly):
#   File "/usr/lib/python3.10/glob.py", line 94, in _glob1
#     names = _listdir(dirname, dir_fd, dironly)
#   File "/usr/lib/python3.10/glob.py", line 164, in _listdir
#     return list(it)
#   File "/usr/lib/python3.10/glob.py", line 149, in _iterdir
#     if not dironly or entry.is_dir():
# ...
