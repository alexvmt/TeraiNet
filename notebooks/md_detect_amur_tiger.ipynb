# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# %cd drive/MyDrive/tiger_detection/
# Out:
# /content/drive/MyDrive/tiger_detection

# %%
# !pwd
# Out:
# /content/drive/MyDrive/tiger_detection

# %%
# !mkdir images/amur_tiger/test

# %%
# !wget -O images/amur_tiger/test/atrw_detection_test.tar.gz https://storage.googleapis.com/public-datasets-lila/cvwc2019/test/atrw_detection_test.tar.gz
# Out:
# --2024-10-22 08:25:12--  https://storage.googleapis.com/public-datasets-lila/cvwc2019/test/atrw_detection_test.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.194.207, 142.251.12.207, 172.253.118.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.194.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1493058467 (1.4G) [application/x-tar]
# Saving to: ‘images/amur_tiger/test/atrw_detection_test.tar.gz’
#
# images/amur_tiger/t 100%[===================>]   1.39G  23.0MB/s    in 64s
#
# 2024-10-22 08:26:17 (22.4 MB/s) - ‘images/amur_tiger/test/atrw_detection_test.tar.gz’ saved [1493058467/1493058467]

# %%
# !tar -xzf images/amur_tiger/test/atrw_detection_test.tar.gz -C images/amur_tiger/test

# %%
# !pip install megadetector
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.5/820.5 kB 42.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.0/706.0 kB 33.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 76.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.3 MB/s eta 0:00:00
# ...

# %%
from megadetector.detection.run_detector_batch import \
  load_and_run_detector_batch, write_results_to_file
from megadetector.utils import path_utils
import os

# %%
image_folder = os.path.expanduser('images/amur_tiger/test/test')
output_file = os.path.expanduser('megadetector_output_amur_tiger_test.json')

# %%
image_file_names = path_utils.find_images(image_folder, recursive=True)

# %%
detector_filename = 'megadetector/md_v5a.0.0.pt'
results = load_and_run_detector_batch(detector_filename, image_file_names)
# Out:
# PyTorch reports 1 available CUDA devices
# GPU available: True
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 3
# wandb: You chose "Don't visualize my results"
# Imported YOLOv5 as utils.*
# Using PyTorch version 2.4.1+cu121
# INFO:yolov5:Fusing layers...
# Fusing layers...
# Fusing layers...
# INFO:yolov5:Model summary: 733 layers, 140054656 parameters, 0 gradients, 208.8 GFLOPs
# Model summary: 733 layers, 140054656 parameters, 0 gradients, 208.8 GFLOPs
# Model summary: 733 layers, 140054656 parameters, 0 gradients, 208.8 GFLOPs
# Sending model to GPU
# Loaded model in 33.17 seconds
# Loaded model in 33.17 seconds
#   0%|          | 0/1651 [00:00<?, ?it/s]
# Processing image images/amur_tiger/test/test/0001.jpg
# ...

# %%
write_results_to_file(results,
                      output_file,
                      relative_path_base=image_folder,
                      detector_file=detector_filename)
# Out:
# Output file saved at megadetector_output_amur_tiger_test.json
# {'images': [{'file': '0001.jpg',
#    'detections': [{'category': '1',
#      'conf': 0.00502,
#      'bbox': [0.5739, 0.2537, 0.007291, 0.0324]},
#     {'category': '2',
#      'conf': 0.0201,
#      'bbox': [0.5749, 0.2527, 0.00677, 0.0324]},
#     {'category': '1',
#      'conf': 0.213,
#      'bbox': [0.7317, 0.5361, 0.08385, 0.09907]},
#     {'category': '1',
#      'conf': 0.96,
#      'bbox': [0.3666, 0.3675, 0.3234, 0.2981]}]},
#   {'file': '0007.jpg',
#    'detections': [{'category': '1',
#      'conf': 0.966,
#      'bbox': [0.3453, 0.2879, 0.588, 0.6768]}]},
#   {'file': '0014.jpg',
#    'detections': [{'category': '2',
#      'conf': 0.0064,
#      'bbox': [0.3411, 0.7101, 0.03541, 0.1074]},
#     {'category': '1', 'conf': 0.00801, 'bbox': [0.3421, 0.7157, 0.03333, 0.1]},
#     {'category': '1',
#      'conf': 0.0156,
#      'bbox': [0.04322, 0.5259, 0.0651, 0.06018]},
# ...
